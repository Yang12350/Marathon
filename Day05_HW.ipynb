# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
import requests
r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
count_number = 0 #宣告整數
data=json.loads(r.text)
for d in data:
    count_number += 1

print('這個 API 一次會回傳%s筆資料' % count_number)
print('每一筆資料包含以下資料:', data[1].keys())
# Out:
# 這個 API 一次會回傳30筆資料
# 每一筆資料包含以下資料: dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」

for d in data:
    print('標題:', d['title'])
    print('貼文時間:', d['createdAt']) 
    print('留言人數:', d['commentCount'])
    print('按讚人數:', d['likeCount'])
    print(" ")
# Out:
# 標題: 寵物溝通讓我起雞皮疙瘩 我信了
# 貼文時間: 2020-05-10T05:06:09.803Z
# 留言人數: 329
# 按讚人數: 6827
#
# 標題: 母愛真偉大！貓媽媽「叼奶貓」闖急診室　暖醫護蹲低看診🐈....
# 貼文時間: 2020-05-10T03:16:00.749Z
# 留言人數: 10
# 按讚人數: 1723
#
# 標題: 我家可愛的肥仔～🐶
# 貼文時間: 2020-05-10T15:19:49.737Z
# 留言人數: 3
# 按讚人數: 107
#
# 標題: 狗界諧星#惡霸犬
# 貼文時間: 2020-05-10T03:48:16.726Z
# 留言人數: 13
# 按讚人數: 57
#
# 標題: 收放自如的肥廢懶貓
# 貼文時間: 2020-05-11T10:19:40.101Z
# 留言人數: 19
# 按讚人數: 34
#
# 標題: 夏天到了！想幫兔兔脫毛大衣
# 貼文時間: 2020-05-10T07:25:46.254Z
# 留言人數: 8
# 按讚人數: 29
#
# 標題: 我家阿肥
# 貼文時間: 2020-05-10T01:32:39.295Z
# 留言人數: 1
# 按讚人數: 25
#
# 標題: 求救 咬人貓
# 貼文時間: 2020-05-10T20:15:32.556Z
# 留言人數: 12
# 按讚人數: 20
#
# 標題: 女兒的奇葩睡姿
# 貼文時間: 2020-05-11T05:01:50.530Z
# 留言人數: 2
# 按讚人數: 15
#
# 標題: 難道這是美瞳威力？
# 貼文時間: 2020-05-10T15:25:48.508Z
# 留言人數: 0
# 按讚人數: 15
#
# 標題: 愛的魔力轉圈圈
# 貼文時間: 2020-05-10T15:15:36.438Z
# 留言人數: 0
# 按讚人數: 15
#
# 標題: 一些關於寵物溝通師的想法
# 貼文時間: 2020-05-11T03:19:33.180Z
# 留言人數: 41
# 按讚人數: 13
#
# 標題: 來蓋兔子樓吧
# 貼文時間: 2020-05-10T20:46:52.129Z
# 留言人數: 7
# 按讚人數: 13
#
# 標題: 黑色米克斯走失
# ...

# %%
import pandas
print('表格化')
cols_name = ['標題', '貼文時間', '留言人數', '按讚人數']
data = pandas.read_json(r.text)
contents = content[['title','createdAt','commentCount','likeCount']]
contents.columns = cols_name
contents
# Out:
# 表格化
#                                  標題                      貼文時間  留言人數  按讚人數
# 0                   寵物溝通讓我起雞皮疙瘩 我信了  2020-05-10T05:06:09.803Z   219  5112
# 1   母愛真偉大！貓媽媽「叼奶貓」闖急診室　暖醫護蹲低看診🐈....  2020-05-10T03:16:00.749Z    10  1458
# 2                         我家可愛的肥仔～🐶  2020-05-10T15:19:49.737Z     2    74
# 3                          狗界諧星#惡霸犬  2020-05-10T03:48:16.726Z    12    41
# 4                     夏天到了！想幫兔兔脫毛大衣  2020-05-10T07:25:46.254Z     8    25
# 5                              我家阿肥  2020-05-10T01:32:39.295Z     1    22
# 6                            求救 咬人貓  2020-05-10T20:15:32.556Z    12    17
# 7                           愛的魔力轉圈圈  2020-05-10T15:15:36.438Z     0    13
# 8                         難道這是美瞳威力？  2020-05-10T15:25:48.508Z     0    11
# 9                            來蓋兔子樓吧  2020-05-10T20:46:52.129Z     6    10
# 10                          女兒的奇葩睡姿  2020-05-11T05:01:50.530Z     0     9
# 11                          黑色米克斯走失  2020-05-10T13:50:30.877Z     1     9
# ...

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

#非熱門文章須把true改成false  https://www.dcard.tw/_api/forums/pet/posts?popular=false
import json
import requests
import pandas
r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
print('熱門文章')
cols_name = ['標題', '貼文時間', '留言人數', '按讚人數']
data = pandas.read_json(r.text)
contents = content[['title','createdAt','commentCount','likeCount']]
contents.columns = cols_name
contents
# Out:
# 熱門文章
#                                  標題                      貼文時間  留言人數  按讚人數
# 0                   寵物溝通讓我起雞皮疙瘩 我信了  2020-05-10T05:06:09.803Z   219  5112
# 1   母愛真偉大！貓媽媽「叼奶貓」闖急診室　暖醫護蹲低看診🐈....  2020-05-10T03:16:00.749Z    10  1458
# 2                         我家可愛的肥仔～🐶  2020-05-10T15:19:49.737Z     2    74
# 3                          狗界諧星#惡霸犬  2020-05-10T03:48:16.726Z    12    41
# 4                     夏天到了！想幫兔兔脫毛大衣  2020-05-10T07:25:46.254Z     8    25
# 5                              我家阿肥  2020-05-10T01:32:39.295Z     1    22
# 6                            求救 咬人貓  2020-05-10T20:15:32.556Z    12    17
# 7                           愛的魔力轉圈圈  2020-05-10T15:15:36.438Z     0    13
# 8                         難道這是美瞳威力？  2020-05-10T15:25:48.508Z     0    11
# 9                            來蓋兔子樓吧  2020-05-10T20:46:52.129Z     6    10
# 10                          女兒的奇葩睡姿  2020-05-11T05:01:50.530Z     0     9
# 11                          黑色米克斯走失  2020-05-10T13:50:30.877Z     1     9
# ...

# %%
import json
import requests
import pandas
ac = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=false')
print('非熱門文章')
col_name = ['標題', '貼文時間', '留言人數', '按讚人數']
data1 = pandas.read_json(ac.text)
contents1 = content[['title','createdAt','commentCount','likeCount']]
contents1.columns = col_name
contents1
# Out:
# 非熱門文章
#                                  標題                      貼文時間  留言人數  按讚人數
# 0                   寵物溝通讓我起雞皮疙瘩 我信了  2020-05-10T05:06:09.803Z   219  5112
# 1   母愛真偉大！貓媽媽「叼奶貓」闖急診室　暖醫護蹲低看診🐈....  2020-05-10T03:16:00.749Z    10  1458
# 2                         我家可愛的肥仔～🐶  2020-05-10T15:19:49.737Z     2    74
# 3                          狗界諧星#惡霸犬  2020-05-10T03:48:16.726Z    12    41
# 4                     夏天到了！想幫兔兔脫毛大衣  2020-05-10T07:25:46.254Z     8    25
# 5                              我家阿肥  2020-05-10T01:32:39.295Z     1    22
# 6                            求救 咬人貓  2020-05-10T20:15:32.556Z    12    17
# 7                           愛的魔力轉圈圈  2020-05-10T15:15:36.438Z     0    13
# 8                         難道這是美瞳威力？  2020-05-10T15:25:48.508Z     0    11
# 9                            來蓋兔子樓吧  2020-05-10T20:46:52.129Z     6    10
# 10                          女兒的奇葩睡姿  2020-05-11T05:01:50.530Z     0     9
# 11                          黑色米克斯走失  2020-05-10T13:50:30.877Z     1     9
# ...

# %%
print('熱門文章的「平均留言人數」為', contents['留言人數'].mean())
print('熱門文章的「平均按讚人數」為', contents['按讚人數'].mean())
print('非熱門文章的「平均留言人數」為', contents1['留言人數'].mean())
print('非熱門文章的「平均按讚人數」為', contents1['按讚人數'].mean())
# Out:
# 熱門文章的「平均留言人數」為 10.866666666666667
# 熱門文章的「平均按讚人數」為 229.73333333333332
# 非熱門文章的「平均留言人數」為 10.866666666666667
# 非熱門文章的「平均按讚人數」為 229.73333333333332
